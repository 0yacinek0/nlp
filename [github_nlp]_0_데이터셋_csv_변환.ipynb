# %% [markdown]
# <a href="https://colab.research.google.com/github/0yacinek0/nlp/blob/practice/%5Bgithub_nlp%5D_0_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B_csv_%EB%B3%80%ED%99%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 네이버 영화 평점 데이터에서 다운로드한 파일들을 (rating_train.txt, rating_test.txt) torchtext에서 로딩이 가능한 형태로 변환

# %%
# !cat rating_train.txt | head -n 10 # 명령어 해당 없음
# Out:
# cat: rating_train.txt: No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd # 현재 경로 확인
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/논문/sentimentP/dataset
# Out:
# /content/drive/MyDrive/논문/sentimentP/dataset

# %%
pwd
# Out:
# '/content/drive/MyDrive/논문/sentimentP/dataset'

# %%
ls
# Out:
# Mecab-ko-for-Google-Colab/  ratings_train.txt  train_data.csv
# ratings_test.txt            test_data.csv

# %% [markdown]
# # TEXT, CSV 파일로 변환 (이후 토큰화)

# %%
# csv파일로 불러오기 
import pandas as pd
columns = ['id', 'text', 'label']
train_data = pd.read_csv('ratings_train.txt', sep='\t', names=columns, skiprows=1).dropna() 
test_data = pd.read_csv('ratings_test.txt', sep='\t', names=columns, skiprows=1).dropna()

# %%
train_data.head()
# Out:
#          id                                               text  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
# 해당 디렉토리 내 csv 파일 저장 
train_data.to_csv('train_data.csv', index=False)

# %%
test_data.to_csv('test_data.csv', index=False)

# %%
# !cat train_data.csv | head -n 5
# Out:
# id,text,label
# 9976970,아 더빙.. 진짜 짜증나네요 목소리,0
# 3819312,흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나,1
# 10265843,너무재밓었다그래서보는것을추천한다,0
# 9045019,교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정,0

# %% [markdown]
# # csv 변환 완료 후 토큰화 (KoNLPy의 은전한닢 tokenizer 이용)

# %% [markdown]
# > @konlpy 모듈 없음 - colab 내 다운로드

# %%
# https://wikidocs.net/94600
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 1.99 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# %cd Mecab-ko-for-Google-Colab
# Out:
# /content/drive/MyDrive/논문/sentimentP/dataset/Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 38.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.6/465.6 KB 37.9 MB/s eta 0:00:00
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2023-01-24 08:42:03--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 18.205.93.0, 18.205.93.2, 18.205.93.1, ...
# Connecting to bitbucket.org (bitbucket.org)|18.205.93.0|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from konlpy.tag import Mecab
mecab = Mecab()

# %%
print(mecab.morphs('이 밤 그날의 반딧불을 당신의 창 가까이 보낼게요'))
# Out:
# ['이', '밤', '그날', '의', '반딧불', '을', '당신', '의', '창', '가까이', '보낼', '게요']

# %% [markdown]
# > torchtext.data importing 에러
# (AttributeError: module 'torchtext.data' has no attribute 'Field')

# %%
# !pip install torchtext==0.10.1 
# !pip install torch==1.8.0 torchtext==0.9.0
"""
아마 예전 코드를 실행하시면서 지금은 사라진 객체를 생성하시려다가 생기는 오류 같습니다.

torchtext 버전을 0.10.x 이나 그 이전으로 낮춰보시는 것은 어떠실까요?
pip install torchtext==0.10.1 과 같은 식으로 버전을 지정하셔서 설치하실 수 있습니다.

https://stackoverflow.com/questions/73055161/importerror-cannot-import-name-unicode-csv-reader-from-torchtext-utils

"""
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# '\n아마 예전 코드를 실행하시면서 지금은 사라진 객체를 생성하시려다가 생기는 오류 같습니다.\n\ntorchtext 버전을 0.10.x 이나 그 이전으로 낮춰보시는 것은 어떠실까요?\npip install torchtext==0.10.1 과 같은 식으로 버전을 지정하셔서 설치하실 수 있습니다.\n\nhttps://stackoverflow.com/questions/73055161/importerror-cannot-import-name-unicode-csv-reader-from-torchtext-utils\n\n'

# %%
import torch
import torchtext
from torchtext.legacy import data

TEXT = torchtext.legacy.data.Field(tokenize=mecab.morphs)
LABLE = torchtext.legacy.data.LabelField(dtype = torch.float)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-64-b5db9825f196> in <module>
#       1 import torch
#       2 import torchtext
# ----> 3 from torchtext.legacy import data
#       4
#       5 TEXT = torchtext.legacy.data.Field(tokenize=mecab.morphs)
#
# /usr/local/lib/python3.8/dist-packages/torchtext/legacy/__init__.py in <module>
# ----> 1 from . import data
#       2 from .. import nn  # Not in the legacy folder
#       3 from . import datasets
#       4 from .. import utils  # Not in the legacy folder
#       5 from .. import vocab  # Not in the legacy folder
#
# /usr/local/lib/python3.8/dist-packages/torchtext/legacy/data/__init__.py in <module>
#       1 from .batch import Batch
#       2 from .example import Example
# ----> 3 from .field import RawField, Field, ReversibleField, SubwordField, NestedField, LabelField
# ...

# %%
torch.__version__
torchtext.__version__
# Out:
# '0.14.1'

# %% [markdown]
# ### 필드 지정

# %%
fields = {'text':('text', TEXT), 'label': ('label', LABEL)}
# dictionary 형식은 {csv컬럼명 : (데이터 컬럼명, Field 이름)}
